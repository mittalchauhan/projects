# %% [raw]
# This data set was very useful when I worked on a project .As a Kaggle contributer I am uploading for others to gain knowledge by implementing algorithms.
#
# Attributes:
# 1.Id(int)
# 2.Date(int)
# 3.number of bedrooms(int)
# 4.number of bathrooms(float)-convert it into 'int' ,just to give you some practice!
# 5.living area(int)
# 6.lot area(int)
# 7.water front present(float)-convert it into 'int'
# 8.number of views(int)
# and so on….

# %%
import numpy as np
import pandas as pd

# %%
df_House_Price_India = pd.read_csv("House Price India.csv")

# %%
#show first 10 rows: 

df_House_Price_India.head(10)
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
# 5  6762813105  42491                   3                 2.50         2600
# 6  6762813157  42491                   5                 3.25         3660
# 7  6762813599  42491                   3                 1.75         2240
# 8  6762813600  42491                   3                 2.50         2390
# 9  6762814461  42491                   4                 2.25         2200
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# ...

# %%
df_House_Price_India.tail(10) #last 10 rows
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14610  6762828349  42734                   4                 2.75
# 14611  6762828783  42734                   3                 1.75
# 14612  6762828856  42734                   3                 1.00
# 14613  6762829600  42734                   3                 1.00
# 14614  6762829669  42734                   3                 1.75
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 14610         1810      7350               1.0                   0
# 14611         1350      7686               1.0                   0
# ...

# %%
#show the shape of the data

df_House_Price_India.shape
# Out:
# (14620, 23)

# %% [markdown]
# **Inference**
#
# - we have 14620 observations in the House Price data.
# - We have 23 attributes on the data.

# %%
#step1 :
#check for null values in data

df_House_Price_India.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %% [markdown]
# **Inference**
#  - we don't have any null values in the data

# %%
#outlier check :
# separate the numerical and categorical data
# catagorical dataframe

df_cat=df_House_Price_India.select_dtypes(include="object")

#numerical Dataframe 
df_num=df_House_Price_India.select_dtypes(include="number")

# %%
df_cat.head(2)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %%
#plot the histogram to authenticate the data
import seaborn as sns
import matplotlib.pyplot as plt


df_num.hist()
plt.tight_layout()
plt.figure
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_num.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
df_num[['id', 'Date', 'number of bedrooms', 'number of bathrooms']]
# Out:
#                id   Date  number of bedrooms  number of bathrooms
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
# [14620 rows x 4 columns]

# %%
df_num.id.plot(kind="hist")
df_num.Date.plot(kind="hist") 
plt.show()

# %%
df_num["number of bedrooms"].plot(kind="hist")
plt.show()

# %%
df_num["number of bathrooms"].plot(kind="hist")
plt.show()

# %%
df_num["living area"].plot(kind="hist")
plt.show()

# %%
df_num["lot area"].plot(kind="kde")
plt.show()

# %%
df_num["waterfront present"].plot(kind="hist")
plt.show()

# %%
df_num["number of views"].plot(kind="hist")
plt.show()

# %%
df_num["condition of the house"].plot(kind="hist")
plt.show()

# %%
df_num["grade of the house"].plot(kind="hist")
plt.show()

# %%
df_num["Area of the house(excluding basement)"].plot(kind="hist")
plt.show()

# %%
df_num["Area of the basement"].plot(kind="hist")
plt.show()

# %%
df_num["Built Year"].plot(kind="hist")
plt.show()

# %%
df_num["Renovation Year"].plot(kind="hist")
plt.show()

# %%
df_num["Postal Code"].plot(kind="hist")
plt.show()

# %%
df_num["Longitude"].plot(kind="hist")
plt.show()

# %%
df_num["Lattitude"].plot(kind="hist")
plt.show()

# %%
df_num["living_area_renov"].plot(kind="hist")
plt.show()

# %%
df_num["lot_area_renov"].plot(kind="hist")
plt.show()

# %%
df_num["Number of schools nearby"].plot(kind="hist")
plt.show()

# %%
df_num["Distance from the airport"].plot(kind="hist")
plt.show()

# %%
df_num["Price"].plot(kind="hist")
plt.show()

# %% [markdown]
# Inference
#
# - the columns need to be catagorical "num of floors, views","cond. of the house", "renov year", 'no. of schools nearby',"waterfrontpresent"

# %%
# change the column datatypes :

df_House_Price_India["number of floors"]=df_House_Price_India["number of floors"].astype("object")

# %%
df_House_Price_India["number of views"]=df_House_Price_India["number of views"].astype("object")

# %%
df_House_Price_India["condition of the house"]=df_House_Price_India["condition of the house"].astype("object")

# %%
df_House_Price_India["Renovation Year"]=df_House_Price_India["Renovation Year"].astype("object")

# %%
df_House_Price_India["Number of schools nearby"]=df_House_Price_India["Number of schools nearby"].astype("object")

# %%
df_House_Price_India["waterfront present"]=df_House_Price_India["waterfront present"].astype("object")

# %%
df_House_Price_India.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14615 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14615 non-null  int64
#  1   Date                                   14615 non-null  int64
#  2   number of bedrooms                     14615 non-null  int64
#  3   number of bathrooms                    14615 non-null  float64
#  4   living area                            14615 non-null  int64
#  5   lot area                               14615 non-null  int64
#  6   number of floors                       14615 non-null  object
#  7   waterfront present                     14615 non-null  int32
#  8   number of views                        14615 non-null  object
#  9   condition of the house                 14615 non-null  object
# ...

# %%
df_House_Price_India["Built Year"]=df_House_Price_India["Built Year"].astype("object")

# %% [markdown]
# ### Access the columns based on their relevance

# %%
df_House_Price_India.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %% [raw]
# id : unique identifier for a house
# Date : when record is insertrd in the db
# number of bedrooms : number of bedrooms in the house
# number of bathrooms :number of bathrooms in the house
# living area : size of linving area
# lot area : plot area of the house
# number of floors : num of floors in the house
# waterfront present : Is water resource present in the house
# number of views : num of views surrounded by the area
# condition of the house : current condition of the house
# grade of the house : grade according to the state of house
# Area of the house(excluding basement) : Area of the house excluding basement
# Area of the basement :Area of the basement if present
# Built Year :  house establishment year
# Renovation Year:Renovation Year if renovation is done
# Postal Code:Postal Code of the area
# Lattitude : lattitude of the location coordinate
# Longitude : Longitude of the location coordinate
# living_area_renov : living area if renovation is done
# lot_area_renov : Plot area that renovated
# Number of schools nearby : Number of schools present nearby
# Distance from the airport : Distance from House to the airport
# Price : price of that house

# %%
# The columns for the Home Coordinate
# 'number of bedrooms','number of bathrooms','living area','lot area',
# 'number of floors','number of views','condition of the house',
# 'grade of the house','Area of the house(excluding basement)',
# 'Area of the basement','Built Year','Renovation Year',
# 'living_area_renov','lot_area_renov','Price'

# Create the dataframe

df_House_Price_India_Home_Coordinate = df_House_Price_India[['number of bedrooms','number of bathrooms','living area','lot area',
'number of floors','number of views','condition of the house',
 'grade of the house','Area of the house(excluding basement)',
 'Area of the basement','Built Year','Renovation Year',
 'living_area_renov','lot_area_renov','Price']]
df_House_Price_India_Home_Coordinate.head(2)
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                  2.5         3650      9050
# 1                   4                  2.5         2920      4000
#
#   number of floors number of views condition of the house  grade of the house  \
# 0              2.0               4                      5                  10
# 1              1.5               0                      5                   8
#
#    Area of the house(excluding basement)  Area of the basement Built Year  \
# 0                                   3370                   280       1921
# 1                                   1910                  1010       1909
#
#   Renovation Year  living_area_renov  lot_area_renov    Price
# 0               0               2880            5400  2380000
# 1               0               2470            4000  1400000

# %%
# Draw the pairplot of given Home Coordinate
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df_House_Price_India_Home_Coordinate)
plt.show()

# %% [markdown]
# **Interpretation**
#  - no of bedrooms vs price : followa the exponential growth
#  - no of bathrooms vs price : Hetroscadestisity : even tho no of bathrooms are more it wont affect the price
#  - living area vs price : Hetroscadestisity : living area is good but won't affect the price
#  - lot area,no of floors,no of views,cond. of the house vs price : no relation
#  - grade of the house vs price: Hetroscadestisity : most grade of the house not making that differnce in price
#  - area of house excluding basement vs price : Hetroscadestisity
#  - area of basement , built year, lot_area_renov vs price : no relation
#  - renovation year vs price : catagorical column
#  - living area renovation vs price : Hetroscadestisity

# %% [markdown]
# - linear graph : 45Degree graph

# %% [markdown]
# - Univariate Analysis on df_House_Price_India_Home _Coordinate

# %%
df_House_Price_India_Home_Coordinate.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                 2.50         3650      9050
# 1                   4                 2.50         2920      4000
# 2                   5                 2.75         2910      9480
# 3                   4                 2.50         3310     42998
# 4                   3                 2.00         2710      4500
#
#   number of floors number of views condition of the house  grade of the house  \
# 0              2.0               4                      5                  10
# 1              1.5               0                      5                   8
# 2              1.5               0                      3                   8
# 3              2.0               0                      3                   9
# 4              1.5               0                      4                   8
#
#    Area of the house(excluding basement)  Area of the basement Built Year  \
# ...

# %%
df_House_Price_India_Home_Coordinate.columns
# Out:
# Index(['number of bedrooms', 'number of bathrooms', 'living area', 'lot area',
#        'number of floors', 'number of views', 'condition of the house',
#        'grade of the house', 'Area of the house(excluding basement)',
#        'Area of the basement', 'Built Year', 'Renovation Year',
#        'living_area_renov', 'lot_area_renov', 'Price'],
#       dtype='object')

# %% [markdown]
# ### number of bedrooms

# %%
#counts the repeatation numbers of distict values in a column
df_House_Price_India_Home_Coordinate['number of bedrooms'].value_counts()
# Out:
# 3     6612
# 4     4724
# 2     1844
# 5     1079
# 6      176
# 1      136
# 7       30
# 8       11
# 9        3
# 10       3
# 33       1
# 11       1
# Name: number of bedrooms, dtype: int64

# %% [markdown]
# **Interpretation**
# - As we can see here, most of the houses who came for sell are 3BHK, 4 BHK and 2 BHK.
# - Observing the last 3 observations of the output, It is very difficult to have no of bedrooms more than 9 in a house, also we know that this is commercial data.

# %% [markdown]
# ### Invastigate the last 3 observations of the previous output

# %%
df_bedroom_gt9 = df_House_Price_India_Home_Coordinate[df_House_Price_India_Home_Coordinate['number of bedrooms']>9]
df_bedroom_gt9.head()
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 3532                   33                 1.75         1620      6000
# 6982                   10                 5.25         4590     10920
# 7454                   11                 3.00         3000      4960
# 11547                  10                 2.00         3610     11914
# 14481                  10                 3.00         2920      3745
#
#       number of floors number of views condition of the house  \
# 3532               1.0               0                      5
# 6982               1.0               2                      3
# 7454               2.0               0                      3
# 11547              2.0               0                      4
# 14481              2.0               0                      4
#
#        grade of the house  Area of the house(excluding basement)  \
# 3532                    7                                   1040
# ...

# %% [markdown]
# **Inference**
# - the house having 33 rooms has its plot size very less also we can see the numbers of bathrooms and floors which shows that this observations are not authenticated.
# - we can see the same pattern in remaining observations
#
# - `Actions`:remove those observations from the main dataframe

# %%
df_bedroom_gt9=df_bedroom_gt9.drop([3532]) #3532 is id
df_bedroom_gt9
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 6982                   10                 5.25         4590     10920
# 7454                   11                 3.00         3000      4960
# 11547                  10                 2.00         3610     11914
# 14481                  10                 3.00         2920      3745
#
#       number of floors number of views condition of the house  \
# 6982               1.0               2                      3
# 7454               2.0               0                      3
# 11547              2.0               0                      4
# 14481              2.0               0                      4
#
#        grade of the house  Area of the house(excluding basement)  \
# 6982                    9                                   2500
# 7454                    7                                   2400
# 11547                   7                                   3010
# ...

# %%
df_House_Price_India_Home_Coordinate=df_House_Price_India_Home_Coordinate[df_House_Price_India_Home_Coordinate['number of bedrooms']<=9]
df_House_Price_India_Home_Coordinate
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                 2.50         3650      9050
# 1                       4                 2.50         2920      4000
# 2                       5                 2.75         2910      9480
# 3                       4                 2.50         3310     42998
# 4                       3                 2.00         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                 1.50         1556     20000
# 14616                   3                 2.00         1680      7000
# 14617                   2                 1.00         1070      6120
# 14618                   4                 1.00         1030      6621
# 14619                   3                 1.00          900      4770
#
#       number of floors number of views condition of the house  \
# 0                  2.0               4                      5
# ...

# %%
df_House_Price_India=df_House_Price_India[df_House_Price_India["number of bedrooms"]<=9]
df_House_Price_India
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area number of floors waterfront present  \
# 0             3650      9050              2.0                  0
# ...

# %%
## authenticate the results
df_House_Price_India_Home_Coordinate['number of bedrooms'].value_counts()
# Out:
# 3    6612
# 4    4724
# 2    1844
# 5    1079
# 6     176
# 1     136
# 7      30
# 8      11
# 9       3
# Name: number of bedrooms, dtype: int64

# %%
df_House_Price_India_Home_Coordinate['number of bedrooms'].value_counts().plot(kind="bar",color="black")
plt.show()

# %% [markdown]
# # Univariate Analysis on number of bathrooms

# %%
df_House_Price_India_Home_Coordinate.columns
# Out:
# Index(['number of bedrooms', 'number of bathrooms', 'living area', 'lot area',
#        'number of floors', 'number of views', 'condition of the house',
#        'grade of the house', 'Area of the house(excluding basement)',
#        'Area of the basement', 'Built Year', 'Renovation Year',
#        'living_area_renov', 'lot_area_renov', 'Price'],
#       dtype='object')

# %%
df_House_Price_India_Home_Coordinate.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                 2.50         3650      9050
# 1                   4                 2.50         2920      4000
# 2                   5                 2.75         2910      9480
# 3                   4                 2.50         3310     42998
# 4                   3                 2.00         2710      4500
#
#   number of floors number of views condition of the house  grade of the house  \
# 0              2.0               4                      5                  10
# 1              1.5               0                      5                   8
# 2              1.5               0                      3                   8
# 3              2.0               0                      3                   9
# 4              1.5               0                      4                   8
#
#    Area of the house(excluding basement)  Area of the basement Built Year  \
# ...

# %%
df_House_Price_India_Home_Coordinate['number of bathrooms']= df_House_Price_India_Home_Coordinate['number of bathrooms'].astype("int")

# %%
#authenticate the action
df_House_Price_India_Home_Coordinate.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                    2         3650      9050
# 1                   4                    2         2920      4000
# 2                   5                    2         2910      9480
# 3                   4                    2         3310     42998
# 4                   3                    2         2710      4500
#
#   number of floors number of views condition of the house  grade of the house  \
# 0              2.0               4                      5                  10
# 1              1.5               0                      5                   8
# 2              1.5               0                      3                   8
# 3              2.0               0                      3                   9
# 4              1.5               0                      4                   8
#
#    Area of the house(excluding basement)  Area of the basement Built Year  \
# ...

# %%
#apply the value count on number of bathrooms column
df_House_Price_India_Home_Coordinate['number of bathrooms'].value_counts()
# Out:
# 2    7209
# 1    5545
# 3    1537
# 4     226
# 0      50
# 5      36
# 6       8
# 8       2
# 7       2
# Name: number of bathrooms, dtype: int64

# %%
df_House_Price_India_Home_Coordinate['number of bathrooms'].value_counts().plot(kind="bar",color="purple")
plt.show()

# %% [markdown]
# **interpretation**
# - Most of the houses have the bathrooms between 1 to 3
# - There is 50 houses having no bathrooms
# - need investigation on the houses having bathrooms 7 and 8

# %%
# Try with round function
df_House_Price_India_Home_Coordinate['number of bathrooms'] = np.round(df_House_Price_India_Home_Coordinate['number of bathrooms'],0)

# %%
#apply the value count on number of bathrooms column
df_House_Price_India_Home_Coordinate['number of bathrooms'].value_counts()
# Out:
# 2    7209
# 1    5545
# 3    1537
# 4     226
# 0      50
# 5      36
# 6       8
# 8       2
# 7       2
# Name: number of bathrooms, dtype: int64

# %% [markdown]
# **Task for class**
#  - Make new dataframe with those 50 records having 0 number of bathrooms. give it a name as "df_zero_bathroooms"
#  - Make another dataframe with those houses having number of bathrooms as 7 and 8

# %% [markdown]
# here, it's not working because of np.round
# otherwise given below query will return the result
# try it on 5_house price file

# %%
# here is the code for it
zero_bathrooms=df_House_Price_India_Home_Coordinate[df_House_Price_India_Home_Coordinate["number of bathrooms"]==0.0]
zero_bathrooms
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 664                     2                    0          650      5360
# 1172                    2                    0          850      7710
# 1283                    1                    0         1170     14149
# 1334                    1                    0          820     59677
# 1382                    1                    0          430      5050
# 2034                    1                    0          560     12120
# 2397                    2                    0         1392     43710
# 2595                    1                    0          420      6720
# 2906                    4                    0         1440     13300
# 3204                    1                    0          380     15000
# 3310                    2                    0         1020      1350
# 3548                    2                    0         1440      3700
# ...

# %%
sevenoreight_bathrooms=df_House_Price_India_Home_Coordinate[(df_House_Price_India_Home_Coordinate["number of bathrooms"]>=7)
                                                           &
                                                           (df_House_Price_India_Home_Coordinate["number of bathrooms"]<=8)]
sevenoreight_bathrooms
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 76                      7                    8        13540    307752
# 6730                    9                    7         4050      6504
# 9171                    6                    7         9890     31374
# 10503                   6                    8        12050     27600
#
#       number of floors number of views condition of the house  \
# 76                 3.0               4                      3
# 6730               2.0               0                      3
# 9171               2.0               4                      3
# 10503              2.5               3                      4
#
#        grade of the house  Area of the house(excluding basement)  \
# 76                     12                                   9410
# 6730                    7                                   4050
# 9171                   13                                   8860
# ...

# %%
## Make a new dataframe for those houses having no bathrooms
df_houses_no_bathrooms = df_House_Price_India_Home_Coordinate[df_House_Price_India_Home_Coordinate['number of bathrooms']==0]
df_houses_no_bathrooms.head()
# Out:
#       number of bedrooms  number of bathrooms  living area  lot area  \
# 664                    2                    0          650      5360
# 1172                   2                    0          850      7710
# 1283                   1                    0         1170     14149
# 1334                   1                    0          820     59677
# 1382                   1                    0          430      5050
#
#      number of floors number of views condition of the house  \
# 664               1.0               0                      4
# 1172              1.0               2                      5
# 1283              1.0               0                      5
# 1334              1.0               0                      3
# 1382              1.0               0                      2
#
#       grade of the house  Area of the house(excluding basement)  \
# 664                    5                                    650
# ...

# %%
# Investigate those houses
# 1. Based on No of bedrooms
df_houses_no_bathrooms["number of bedrooms"].value_counts()
# Out:
# 2    21
# 1    17
# 3     9
# 4     3
# Name: number of bedrooms, dtype: int64

# %% [markdown]
# **Interpretation**
# - There is 21 houses with 2 bedrooms having no bathrooms in it
# - Need investigation on houses having 4 bedrooms

# %%
#Investigate the houses having 4 bedrooms without bathrooms
df_houses_no_bathrooms[df_houses_no_bathrooms["number of bedrooms"]>= 4]
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 2906                    4                    0         1440     13300
# 13912                   4                    0         2300      5570
# 14353                   4                    0         1960      8277
#
#       number of floors number of views condition of the house  \
# 2906               1.0               0                      3
# 13912              2.0               0                      3
# 14353              1.0               4                      4
#
#        grade of the house  Area of the house(excluding basement)  \
# 2906                    6                                   1440
# 13912                   8                                   2300
# 14353                   7                                   1320
#
#        Area of the basement Built Year Renovation Year  living_area_renov  \
# 2906                      0       1948               0               1460
# ...

# %% [markdown]
# **Interpretation**
# - As we can observe the data, everything is right in it, so no need to analyse more
# - the houses are build in 90's , in that time our psychology is not allow us to take bathrooms in house, there is religious and other factors who affecting it, because that people habitual to add bathrooms in houses.
#
# **Action: Based on the scenario we can decide to remove those from the main data**

# %%
# Do the changes in home coordinate
df_House_Price_India_Home_Coordinate=df_House_Price_India_Home_Coordinate[df_House_Price_India_Home_Coordinate["number of bathrooms"]!=0]

# %%
# Do the changes in main data
df_House_Price_India_Home_Coordinate=df_House_Price_India_Home_Coordinate[df_House_Price_India_Home_Coordinate["number of bathrooms"]!=0]

# %% [markdown]
# # Univariate Analysis on living area

# %%
df_House_Price_India_Home_Coordinate.columns
# Out:
# Index(['number of bedrooms', 'number of bathrooms', 'living area', 'lot area',
#        'number of floors', 'number of views', 'condition of the house',
#        'grade of the house', 'Area of the house(excluding basement)',
#        'Area of the basement', 'Built Year', 'Renovation Year',
#        'living_area_renov', 'lot_area_renov', 'Price'],
#       dtype='object')

# %%
# whenever you deal with any numerical column analyse first find minimum and maximum
# the find mean and meadian
df_House_Price_India_Home_Coordinate["living area"].min()
# Out:
# 460

# %%
# Find the maximum value
df_House_Price_India_Home_Coordinate["living area"].max()
# Out:
# 13540

# %%
# Find the mean of the column (Average)
df_House_Price_India_Home_Coordinate["living area"].mean()
# Out:
# 2101.954205286646

# %%
# Find the median
df_House_Price_India_Home_Coordinate["living area"].median()
# Out:
# 1940.0

# %% [markdown]
# ### normal distribution in statistics
# - In normal distribution in statistics mean=median
# - we find normal distributionon on numerical column not on categorical column

# %%
# Find the difference between mean and median
df_House_Price_India_Home_Coordinate["living area"].mean() - df_House_Price_India_Home_Coordinate["living area"].median()
# Out:
# 161.9542052866459

# %%
# Lets prove that data is not normally distributed
import seaborn as sns
import matplotlib.pyplot as plt

sns.kdeplot(df_House_Price_India_Home_Coordinate["living area"])
plt.show()

# %% [markdown]
# **Interpretation**
# - as we see here, data is normally distributed
# - most of the houses having living area between 360 to 4000 sqft.

# %%
#fetch out the houses having living area greater than 10000
df_living_area_greater_10000 = df_House_Price_India_Home_Coordinate[df_House_Price_India_Home_Coordinate["living area"]>10000]

# %%
df_living_area_greater_10000.head()
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 76                      7                    8        13540    307752
# 2424                    5                    4        10040     37325
# 10503                   6                    8        12050     27600
#
#       number of floors number of views condition of the house  \
# 76                 3.0               4                      3
# 2424               2.0               2                      3
# 10503              2.5               3                      4
#
#        grade of the house  Area of the house(excluding basement)  \
# 76                     12                                   9410
# 2424                   11                                   7680
# 10503                  13                                   8570
#
#        Area of the basement Built Year Renovation Year  living_area_renov  \
# 76                     4130       1999               0               4850
# ...

# %% [markdown]
# **Interpretation**
# - As we see here there is nothing for observations
# - we compare Area of the house(excluding basement) and Area of the basementby adding them we conclude the living area of the houses
# - also the houses having larger prices are renovated

# %%
df_House_Price_India_Home_Coordinate.columns
# Out:
# Index(['number of bedrooms', 'number of bathrooms', 'living area', 'lot area',
#        'number of floors', 'number of views', 'condition of the house',
#        'grade of the house', 'Area of the house(excluding basement)',
#        'Area of the basement', 'Built Year', 'Renovation Year',
#        'living_area_renov', 'lot_area_renov', 'Price'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis on Lot Area

# %% [markdown]
# - Task1 : Generate the KDE plot on lot area column
# - Task2 : Print the maximum and minimum value
# - Task3 : Generate the scatter plot
# - Task4 : Write the inference and fetch out the odd records if needed

# %%
# Lets prove that data is not normally distributed
import seaborn as sns
import matplotlib.pyplot as plt

sns.kdeplot(df_House_Price_India_Home_Coordinate["lot area"])
plt.show()

# %%
# Find the maximum value
df_House_Price_India_Home_Coordinate["lot area"].max()
# Out:
# 1074218

# %%
# Find the minimum value
df_House_Price_India_Home_Coordinate["lot area"].min()
# Out:
# 520

# %% [markdown]
# # D. Univariate Analysis on number of floors

# %%
#Task1 : Show the first 5 records of home coordinate
#Task2 : Show the columns of the same dataframe
#Task3 : change the datatype of that same column
#Task4 : show the count of each category
#Task5 : plot the countplot for the same column

# %%
#Task1
df_House_Price_India_Home_Coordinate.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                    2         3650      9050
# 1                   4                    2         2920      4000
# 2                   5                    2         2910      9480
# 3                   4                    2         3310     42998
# 4                   3                    2         2710      4500
#
#   number of floors number of views condition of the house  grade of the house  \
# 0              2.0               4                      5                  10
# 1              1.5               0                      5                   8
# 2              1.5               0                      3                   8
# 3              2.0               0                      3                   9
# 4              1.5               0                      4                   8
#
#    Area of the house(excluding basement)  Area of the basement Built Year  \
# ...

# %%
#task2
df_House_Price_India_Home_Coordinate.columns
# Out:
# Index(['number of bedrooms', 'number of bathrooms', 'living area', 'lot area',
#        'number of floors', 'number of views', 'condition of the house',
#        'grade of the house', 'Area of the house(excluding basement)',
#        'Area of the basement', 'Built Year', 'Renovation Year',
#        'living_area_renov', 'lot_area_renov', 'Price'],
#       dtype='object')

# %%
#Task3
df_House_Price_India_Home_Coordinate["number of floors"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 14565 entries, 0 to 14619
# Series name: number of floors
# Non-Null Count  Dtype
# --------------  -----
# 14565 non-null  object
# dtypes: object(1)
# memory usage: 227.6+ KB

# %%
df_House_Price_India_Home_Coordinate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14565 entries, 0 to 14619
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   number of bedrooms                     14565 non-null  int64
#  1   number of bathrooms                    14565 non-null  int32
#  2   living area                            14565 non-null  int64
#  3   lot area                               14565 non-null  int64
#  4   number of floors                       14565 non-null  object
#  5   number of views                        14565 non-null  object
#  6   condition of the house                 14565 non-null  object
#  7   grade of the house                     14565 non-null  int64
#  8   Area of the house(excluding basement)  14565 non-null  int64
#  9   Area of the basement                   14565 non-null  int64
# ...

# %%
df_House_Price_India_Home_Coordinate["number of floors"] = df_House_Price_India_Home_Coordinate["number of floors"].astype("float")

# %%
df_House_Price_India_Home_Coordinate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14565 entries, 0 to 14619
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   number of bedrooms                     14565 non-null  int64
#  1   number of bathrooms                    14565 non-null  int32
#  2   living area                            14565 non-null  int64
#  3   lot area                               14565 non-null  int64
#  4   number of floors                       14565 non-null  float64
#  5   number of views                        14565 non-null  object
#  6   condition of the house                 14565 non-null  object
#  7   grade of the house                     14565 non-null  int64
#  8   Area of the house(excluding basement)  14565 non-null  int64
#  9   Area of the basement                   14565 non-null  int64
# ...

# %%
df_House_Price_India_Home_Coordinate.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                    2         3650      9050
# 1                   4                    2         2920      4000
# 2                   5                    2         2910      9480
# 3                   4                    2         3310     42998
# 4                   3                    2         2710      4500
#
#    number of floors number of views condition of the house  \
# 0               2.0               4                      5
# 1               1.5               0                      5
# 2               1.5               0                      3
# 3               2.0               0                      3
# 4               1.5               0                      4
#
#    grade of the house  Area of the house(excluding basement)  \
# 0                  10                                   3370
# 1                   8                                   1910
# ...

# %%
df_House_Price_India_Home_Coordinate["number of floors"] = df_House_Price_India_Home_Coordinate["number of floors"].round()

# %%
df_House_Price_India_Home_Coordinate.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                    2         3650      9050
# 1                   4                    2         2920      4000
# 2                   5                    2         2910      9480
# 3                   4                    2         3310     42998
# 4                   3                    2         2710      4500
#
#    number of floors number of views condition of the house  \
# 0               2.0               4                      5
# 1               2.0               0                      5
# 2               2.0               0                      3
# 3               2.0               0                      3
# 4               2.0               0                      4
#
#    grade of the house  Area of the house(excluding basement)  \
# 0                  10                                   3370
# 1                   8                                   1910
# ...

# %%
#Task 3
df_House_Price_India_Home_Coordinate['number of floors'] = df_House_Price_India_Home_Coordinate['number of floors'].astype("int")

# %%
#Task4
df_House_Price_India_Home_Coordinate['number of floors'].value_counts()
# Out:
# 2    7085
# 1    7058
# 3     418
# 4       4
# Name: number of floors, dtype: int64

# %%
#Task 5
df_House_Price_India_Home_Coordinate['number of floors'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >
