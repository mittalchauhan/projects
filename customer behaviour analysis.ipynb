# %%
# CODE HERE
# required libraries
import pandas as pd
import numpy as np

# to acess data values
dataset1=pd.read_csv("DATA1.csv")

# show dataset
dataset1
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
# to show first five records
dataset1.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
# to show last five records
dataset1.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 550063                 NaN                 NaN       368
# ...

# %%
# to show columns
dataset1.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %% [markdown]
# **Inference**
# - `User_ID`: Represents unique identifiers for users.
# - `Product_ID`: Represents unique identifiers for products.
# - `Gender`: Indicates the gender of the customer.
# - `Age`: Represents the age of the customer.
# - `Occupation`: Describes the occupation of the customer.
# - `City_Category`: Represents the category of the city where the customer is located.
# - `Stay_In_Current_City_Years`: Indicates how long the customer has stayed in their current city.
# - `Marital_Status`: Represents whether the customer is married or not.
# - `Product_Category_1`, `Product_Category_2`, `Product_Category_3`: Describes the category of the purchased products.
# - `Purchase`: Represents the purchase amount.

# %%
# shape of the data
dataset1.shape
# Out:
# (550068, 12)

# %% [markdown]
# **Inference**
# - dataset has 550068 observations and 12 columns

# %%
# discribe the data
dataset1.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %% [markdown]
# **Inference**
# - outlier is present at given columns
# - Occupation,Marital_Status,Product_Category_1,Product_Category_2
# - means data is not norally distributed but outlier is very low so its very close to normal distribution

# %%
# infomation about data
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %% [markdown]
# **Inference**
# - here marital status is int but it shoul be object
# - occupation shold bw int
# - so change their data types

# %%
# change datatype for marital status
dataset1["Marital_Status"]=dataset1["Marital_Status"].astype("object")

# %%
# change datatype for oocupation
dataset1["Occupation"]=dataset1["Occupation"].astype("int")

# %%
# agin show dataset info
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int32
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  object
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int32(1), int64(3), object(6)
# ...

# %%
# check for null values
dataset1.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %% [markdown]
# **Inference**
# - product category 3 and 2 has more number of null values

# %%
# to fill the null values
dataset1["Product_Category_2"].fillna(dataset1["Product_Category_2"].mean(),inplace=True)

# %%
# to fill the null values
dataset1["Product_Category_3"].fillna(dataset1["Product_Category_3"].mean(),inplace=True)

# %%
# check for null values
dataset1.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# **Inference**
# - null values removed

# %%
# to find numerical columns
df_num=dataset1.select_dtypes(include="int")
df_num
# Out:
#         User_ID  Occupation  Product_Category_1  Purchase
# 0       1000001          10                   3      8370
# 1       1000001          10                   1     15200
# 2       1000001          10                  12      1422
# 3       1000001          10                  12      1057
# 4       1000002          16                   8      7969
# ...         ...         ...                 ...       ...
# 550063  1006033          13                  20       368
# 550064  1006035           1                  20       371
# 550065  1006036          15                  20       137
# 550066  1006038           1                  20       365
# 550067  1006039           0                  20       490
#
# [550068 rows x 4 columns]

# %%
# to categorical columns
df_cat=dataset1.select_dtypes(include="object")
df_cat
# Out:
#        Product_ID Gender    Age City_Category Stay_In_Current_City_Years  \
# 0       P00069042      F   0-17             A                          2
# 1       P00248942      F   0-17             A                          2
# 2       P00087842      F   0-17             A                          2
# 3       P00085442      F   0-17             A                          2
# 4       P00285442      M    55+             C                         4+
# ...           ...    ...    ...           ...                        ...
# 550063  P00372445      M  51-55             B                          1
# 550064  P00375436      F  26-35             C                          3
# 550065  P00375436      F  26-35             B                         4+
# 550066  P00375436      F    55+             C                          2
# 550067  P00371644      F  46-50             B                         4+
#
#        Marital_Status
# 0                   0
# 1                   0
# ...

# %%
# to find numerical columns having decimal values
df_float=dataset1.select_dtypes(include="float")
df_float
# Out:
#         Product_Category_2  Product_Category_3
# 0                 9.842329           12.668243
# 1                 6.000000           14.000000
# 2                 9.842329           12.668243
# 3                14.000000           12.668243
# 4                 9.842329           12.668243
# ...                    ...                 ...
# 550063            9.842329           12.668243
# 550064            9.842329           12.668243
# 550065            9.842329           12.668243
# 550066            9.842329           12.668243
# 550067            9.842329           12.668243
#
# [550068 rows x 2 columns]

# %%
dataset1["Product_Category_1"].max()
dataset1["Product_Category_2"].max()
dataset1["Product_Category_3"].max()
dataset1["Purchase"].max()
dataset1["Product_ID"].max()
dataset1["Occupation"].max()
# Out:
# 20

# %%
# visual representation
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(dataset1)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Inference**
# - we have 6 columns with categorical values
# - we have 6 columns with numerical values where 4 are integer type and 2 are folat
# - here mostly we have no relation shown within pairplot

# %%
dataset1["Occupation"].isnull().sum()
# Out:
# 0

# %%
dataset1["Occupation"].value_counts()
# Out:
# 4     72308
# 0     69638
# 7     59133
# 1     47426
# 17    40043
# 20    33562
# 12    31179
# 14    27309
# 2     26588
# 16    25371
# 6     20355
# 3     17650
# 10    12930
# 5     12177
# 15    12165
# 11    11586
# 19     8461
# 13     7728
# 18     6622
# 9      6291
# 8      1546
# Name: Occupation, dtype: int64

# %% [markdown]
# *Inference**
# - here occupation has no value
# - by value count it shows more than 60000 null data
# - so we need to clean it by removing that values

# %%
dataset1=dataset1[dataset1["Occupation"]>0]

# %%
dataset1["Occupation"].value_counts()
# Out:
# 4     72308
# 7     59133
# 1     47426
# 17    40043
# 20    33562
# 12    31179
# 14    27309
# 2     26588
# 16    25371
# 6     20355
# 3     17650
# 10    12930
# 5     12177
# 15    12165
# 11    11586
# 19     8461
# 13     7728
# 18     6622
# 9      6291
# 8      1546
# Name: Occupation, dtype: int64

# %%
dataset1["Purchase"].plot(kind="kde",color="green")
plt.title("Distribution of Purchase",color="purple")
plt.xlabel("Count",color="purple")
plt.ylabel("Purchase",color="purple")
plt.xticks(rotation=45,color="gold")
plt.yticks(color="gold")
plt.show()

# %% [markdown]
# **Inference**
# - most of the purchases are between 200 to 20000
# - more no of customers here who had purchase arround 9000

# %%
dataset1["Occupation"].plot(kind="hist")
plt.title("Occupation by Purchase ",color="purple")
plt.xlabel("Count",color="purple")
plt.ylabel("Occupation",color="purple")
plt.xticks(rotation=45,color="gold")
plt.yticks(color="gold")
plt.show()

# %% [markdown]
# **Inference**
# - mostly user has 2 occupation

# %%
dataset1["Product_Category_1"].plot(kind="hist")
plt.title("Product_Category_1 by Purchase ",color="purple")
plt.xlabel("Count",color="purple")
plt.ylabel("Product_Category_1",color="purple")
plt.xticks(rotation=45,color="gold")
plt.yticks(color="gold")
plt.show()

# %%
dataset1["Product_Category_2"].plot(kind="hist")
plt.title("Product_Category_2 by Purchase ",color="purple")
plt.xlabel("Count",color="purple")
plt.ylabel("Product_Category_2",color="purple")
plt.xticks(rotation=45,color="gold")
plt.yticks(color="gold")
plt.show()

# %%
dataset1["Product_Category_3"].plot(kind="hist")
plt.title("Product_Category_3 by Purchase ",color="purple")
plt.xlabel("Count",color="purple")
plt.ylabel("Product_Category_3",color="purple")
plt.xticks(rotation=45,color="gold")
plt.yticks(color="gold")
plt.show()

# %%
dataset1["User_ID"].plot(kind="hist")
plt.title("User_ID by Purchase ",color="purple")
plt.xlabel("Count",color="purple")
plt.ylabel("User_ID",color="purple")
plt.xticks(rotation=45,color="gold")
plt.yticks(color="gold")
plt.show()

# %% [markdown]
# **Inference**
# - most puchase for product category 3 is arround 35000
# - most puchase for product category 2 is arround 16000
# - most puchase for product category 1 is arround 14000
